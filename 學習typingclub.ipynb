# %% [markdown]
# <a href="https://colab.research.google.com/github/pika311435/Typing-club/blob/main/%E5%AD%B8%E7%BF%92typingclub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **學習 Colab 環境**

# %% [markdown]
# 修改最上面"修改此檔名.ipynb" 檔名: **學習typingclub.ipynb**

# %% [markdown]
# 嘗試，使用下面圖案的紅框
#
# *   新增程式碼，新增文字
# *   刪除程式碼，刪除文字

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **新增文字**
#
# 1.   新增文字
# 2.   輸入"我是南大附中高二學生，???，這是我輸入的文字"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 新增文字 colab
# 輸入"我是南大附中高二學生，**蘇奇彬**，這是我輸入的文字"
# hello
# pika
#
#
#
# 1.   清單項目1
# 2.   清單項目2

# %% [markdown]
# **新增程式碼**
#
# 1.   print("Hello World")
# 2.   執行
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# **刪除下面的文字區塊**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **先持行下面程式碼，再刪除下面的程式碼區塊**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **學習 TypingClub 環境**

# %% [markdown]
# Google: **TypingClub** [連結文字](https://www.typingclub.com/)

# %% [markdown]
# ##註冊

# %% [markdown]
# *   新註冊
# *   以 google 帳號，註冊登入

# %% [markdown]
# ##第一關的影片 [連結文字](https://www.edclub.com/sportal/program-3/116.play)

# %% [markdown]
# 看完後，**請說明影片重點**
# 1.   進行打字，打完每一字將手放在鍵盤指定位置

# %% [markdown]
# ##英打的想法

# %% [markdown]
# 1.   「慢慢打」：追求「絲滑感」，而非爆發力
# 2.   「忙中有錯」：寧可慢，也不要錯
# 3.   「不要低頭」：封印視覺，啟動觸覺
# 4.   「不要怕錯誤」：錯誤是為了校準大腦，錯越多，越厲害
#
# 給你們講一個台大畢業的漂亮長髮姊姊，她發生的真實故事。

# %% [markdown]
# 從前我應徵上某單位，剛進去工作時，發現，有一個
# ....
#
# 另一個也是台大畢業的短髮姊姊，已經結婚.....

# %% [markdown]
# # **紀錄 TypingClub 學習成果**

# %% [markdown]
# 對高中生「學程式」的關鍵關卡，建議如果你是為了寫程式，請特別留意以下幾段關卡：
#
# 第 317 - 346 關（Symbols）： 練習 $, &, #, *, @, ( ), !, %, ^。這些在變數宣告和邏輯判斷中極常用。
#
# 第 404 - **418** 關（More Symbols）： 這區最重要！ 練習 { }, \, |, <, >。這是寫 C++、Java 或 Python 縮排與語法結構的命脈。

# %% [markdown]
# 請學會 **Ctrl + win + s**，擷取畫面如下

# %% [markdown]
# ![螢幕擷取畫面 2026-04-01 001734.png](data:image/png;base64,...)

# %% [markdown]
# 我的成績擷取畫面如下

# %% [markdown]
# Ctrl + V 張貼於此
#
#
# ---

# %%
#計算成績方式
import math

total_level = 418
my_level = 418 # 假設打到第 50 關

# 使用 round(數字, 小數點位數)
score = round(math.sqrt(my_level / total_level) * 100, 2)

print("我的進度分數是：", score)
# Out:
# 我的進度分數是： 100.0

# %% [markdown]
# ## **我的進度分數是：100.0

# %% [markdown]
# #**學習在 GitHub， new 一個 repository**

# %% [markdown]
# ## 註冊

# %% [markdown]
# *   新註冊
# *   以 google 帳號，註冊登入

# %% [markdown]
# ## new repository

# %% [markdown]
# ###如下圖**紅框**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### new repository: **TypingClub**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **儲存此記事本: 學習typingclub.ipynb**

# %% [markdown]
# ##1. 在Colab儲存

# %% [markdown]
# 1.   **Ctrl + s**
# 2.   儲存成功

# %% [markdown]
# ##2. 在GitHub中儲存副本

# %% [markdown]
# ### 檔案 > **在GitHub中儲存副本**

# %% [markdown]
# 選擇 GitHub **哪一個 repository**
#
# 注意**紅框**的部分

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###

# %% [markdown]
# #**詢問 AI，如何公布GitHub的repository**

# %% [markdown]
# 方便老師檢查學習過程
#
# *   建議使用 **google gemini**
# *   如何公布GitHub 含此記事本的repository: **TypingClub**

# %% [markdown]
# # **請檢查你的作業，本次作業清明節4月5日截止**
